# %% [markdown]
# <a href="https://colab.research.google.com/github/hongwon2/Python-Practice/blob/main/bigquery_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
# Out:
# Authenticated

# %%
# %load_ext google.colab.data_table

# %%
# %%bigquery --project ringed-marker-347607
# select
#   stamp
# from ch3.access_log
# Out:
#                  stamp
# 0  2016-08-26 12:02:00
# 1  2016-08-26 12:02:01
# 2  2016-08-26 12:02:01

# %%
# %%bigquery --project ringed-marker-347607 df
# select
#   stamp
# from ch3.access_log

# %%
df.describe()
# Out:
#                       stamp
# count                     3
# unique                    2
# top     2016-08-26 12:02:01
# freq                      2

# %%
# %%bigquery --project ringed-marker-347607 df
# CREATE TABLE ch3.mst_users2(
#     user_id         STRING
#   , register_date   STRING
#   , register_device NUMERIC
# );

# %%
# %%bigquery --project ringed-marker-347607
# INSERT INTO ch3.mst_users2
# VALUES
#     ('U001', '2016-08-26', 1)
#   , ('U002', '2016-08-26', 2)
#   , ('U003', '2016-08-27', 3)
# ;
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery --project ringed-marker-347607
# SELECT
# 	USER_ID
# 	, CASE
# 		WHEN register_device = 1 THEN '데스크톱'
# 		WHEN register_device = 2 THEN '스마트폰'
# 		WHEN register_device = 3 THEN '애플리케이션'
# 		-- 디폴트 값을 지정할 경우 ELSE 구문을 사용합니다.
# 		-- ELSE ''
# 	END AS device_name
# FROM ch3.mst_users
# ;
# Out:
#   USER_ID device_name
# 0    U001        데스크톱
# 1    U002        스마트폰
# 2    U003      애플리케이션
